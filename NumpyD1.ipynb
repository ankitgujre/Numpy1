# %%
import numpy as np

x = ([[1,2,3,4,5,]])
x
# Out:
# [[1, 2, 3, 4, 5]]

# %%
for i in x:
    for c in i:
        print(c)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for d in np.nditer(x):
    print(d)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# indexing check karne ke liye

for i,d in np.ndenumerate(x):
    print(i,d)
# Out:
# (0, 0) 1
# (0, 1) 2
# (0, 2) 3
# (0, 3) 4
# (0, 4) 5

# %%
k = np.zeros(3)
k
# Out:
# array([0., 0., 0.])

# %%
p = np.empty([9,2])
p

e = np.empty([9,2], dtype=int)
e
# Out:
# array([[31244194863382593, 30399718394495086],
#        [29555332122607727, 32369759767429230],
#        [28429432215765103, 31525674135060596],
#        [32651513917735013,  9007671708418153],
#        [30399800003199075, 31244194863382628],
#        [28429393556668532, 30681249209319456],
#        [32651531097210992, 29555010000126053],
#        [28147931469906029, 28429470870339689],
#        [          7929964,        4294967296]])

# %%
k = np.ones(3)
k
# Out:
# array([1., 1., 1.])

# %%
k = np.eye(3)
k
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])
